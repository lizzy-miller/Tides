# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from shapely import wkt

# %%
beach = pd.read_csv("ASBPA.csv")  
beach = beach.drop('Sand Source Location', axis=1)
beach = beach.drop('Sand Source Type', axis=1)
beach = beach.drop('Project Type', axis=1)
beach = beach.drop('RSM', axis=1)

# %%
beach
# Out:
#      State           Project Name  Year  Length (ft)  Volume (cy)  \
# 0       AK              Ninilchik  2010          NaN      12296.0
# 1       AK            Nome Harbor  2010          NaN      25965.0
# 2       AK            Nome Harbor  2011          NaN      34109.0
# 3       AK            Nome Harbor  2013          NaN      20570.0
# 4       AK            Nome Harbor  2014          NaN      54283.0
# ...    ...                    ...   ...          ...          ...
# 3624    WI   SHEBOYGAN HARBOR, WI  1991          NaN      46577.0
# 3625    WI  TWO RIVERS HARBOR, WI  1997          NaN      49035.0
# 3626    WI  TWO RIVERS HARBOR, WI  2000          NaN      41072.0
# 3627    WI  TWO RIVERS HARBOR, WI  2005          NaN      43189.0
# 3628    WI  TWO RIVERS HARBOR, WI  2009          NaN      89750.0
#
#            Sand Source Name   Latitude   Longitude
# 0                       NaN  60.018889 -151.587500
# 1                       NaN  64.497778 -165.431389
# ...

# %%
print(beach['State'].where(df['Rating_Score'] < 50))
